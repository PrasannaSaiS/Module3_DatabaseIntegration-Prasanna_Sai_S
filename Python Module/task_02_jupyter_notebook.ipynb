# %% [markdown]
# # Task 2: Jupyter Notebook
# **Name:** Prasanna Sai
# **Objective:** Create Jupyter notebook.
# **Task:** Basic notebook operations.
#
# This notebook demonstrates basic operations, including math cells and code cells.

# %% [markdown]
# ## Math Cell Example
# Here is a mathematical equation represented in LaTeX:
#
# $$E = mc^2$$
#
# And the quadratic formula:
#
# $$x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$

# %%
# Code Cell Example
print("Hello from Jupyter Notebook!")

# Basic math operations
a = 5
b = 10
print(f"{a} + {b} = {a + b}")
